# %% [markdown]
# # Setting up

# %%
# Setting up

import warnings
warnings.filterwarnings('ignore')

import pickle

import mlflow
import numpy as np
import pandas as pd

from sklearn.feature_extraction import DictVectorizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

import xgboost as xgb
from hyperopt import fmin, tpe, hp, STATUS_OK, Trials
from hyperopt.pyll import scope

# %%
import mlflow
mlflow.set_tracking_uri("sqlite:///mlflow.db")
mlflow.set_experiment("house-price-prediction")
# Out:
# <Experiment: artifact_location='./mlruns/1', experiment_id='1', lifecycle_stage='active', name='house-price-prediction', tags={}>

# %%
RANDOM_SEED=42

# %% [markdown]
# # Reading data

# %%
def read_data(filename):
    df = pd.read_csv(filename)
    
    df = df.drop(df[(df['GrLivArea']>4000) & (df['SalePrice']<300000)].index)
    df['TotalSF'] = df['TotalBsmtSF'] + df['1stFlrSF'] + df['2ndFlrSF']
    
    return df

# %%
train = read_data('../data/train.csv')

# %% [markdown]
# # Data Processing

# %%
def prepare_features(df: pd.DataFrame, dv=None):
    
    df_label = df.SalePrice.values
    df.drop(['SalePrice'], axis=1, inplace=True) 
    
    num_to_categ_cols = ['MSSubClass', 'OverallCond', 'YrSold', 'MoSold']
    df[num_to_categ_cols] = df[num_to_categ_cols].astype(str)
    
    df_dict = df.to_dict("records")
    df_processed = dv.fit_transform(df_dict)
    
    return df_processed, df_label, dv

# %%
dv = DictVectorizer(sparse=True)

X, y, dv = prepare_features(train, dv)

# %%
def split_dataset(X, y, split_sizes=[0.8, 0.5], random_seed=42):
    X_train, X_rem, y_train, y_rem = train_test_split(X, y, 
        train_size=split_sizes[0], 
        random_state=random_seed)
    X_valid, X_test, y_valid, y_test = train_test_split(X_rem, y_rem, 
        test_size=split_sizes[1], 
        random_state=random_seed)
    return X_train, y_train, X_valid, y_valid, X_test, y_test

# %%
X_train, y_train, X_valid, y_valid, X_test, y_test = split_dataset(X, y, random_seed=RANDOM_SEED)

# %% [markdown]
# # Training

# %%
train_xgb = xgb.DMatrix(X_train, label=y_train)
valid_xgb = xgb.DMatrix(X_valid, label=y_valid)
test_xgb = xgb.DMatrix(X_test, label=y_test)

# %%
def train_model_search(train, valid, test, y_test):
    def objective(params):
        with mlflow.start_run():
            mlflow.set_tag("model", "xgboost")
            mlflow.log_params(params)

            model_xgb = xgb.train(
                params=params,
                dtrain=train,
                evals=[(valid, 'validation')],
                num_boost_round=100,
                early_stopping_rounds=50,   
            )

            y_pred = model_xgb.predict(test)
            rmse = mean_squared_error(y_test, y_pred, squared=False)
            mlflow.log_metric("rmse", rmse)

        return {'loss': rmse, 'status': STATUS_OK}
    
    search_space = {
        'gamma': hp.loguniform('gamma', -5, -1),
        'colsample_bytree' : hp.uniform('colsample_bytree', 0.3,1),
        'subsample': hp.uniform('subsample', 0.4,1),
        'max_depth': scope.int(hp.quniform('max_depth', 3, 10, 1)),
        'learning_rate': hp.loguniform('learning_rate', -3, 0),
        'reg_alpha': hp.loguniform('reg_alpha', -5, -1),
        'reg_lambda': hp.loguniform('reg_lambda', -6, -1),
        'min_child_weight': hp.loguniform('min_child_weight', -1, 3),
        'objective': 'reg:linear',
        'seed': RANDOM_SEED
    }
    
    best_result = fmin(
        fn=objective,
        space=search_space,
        algo=tpe.suggest,
        max_evals=10,
        trials=Trials()
    )
    
    return

# %%
train_model_search(train_xgb, valid_xgb, test_xgb, y_test)
# Out:
# [12:53:10] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation-rmse
# [41]	validation-rmse:31438.09909
# [42]	validation-rmse:31338.18360
# [43]	validation-rmse:31614.86172
# [44]	validation-rmse:31816.33646
# [45]	validation-rmse:31644.06236
# [46]	validation-rmse:31689.27585
# [47]	validation-rmse:31657.61865
# [48]	validation-rmse:31598.09559
# [49]	validation-rmse:31409.89256
# [50]	validation-rmse:31274.07330
# [51]	validation-rmse:31071.87375
# [52]	validation-rmse:31102.50604
# [53]	validation-rmse:31293.40769
# [54]	validation-rmse:31379.35553
# [55]	validation-rmse:31374.11340
# [56]	validation-rmse:31492.86412
# [12:53:13] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation-rmse:98740.67854
# [1]	validation-rmse:53940.99114
# [2]	validation-rmse:38559.66615
# [3]	validation-rmse:33009.44615
# [4]	validation-rmse:29944.30382
# [5]	validation-rmse:29031.44414
# [6]	validation-rmse:28831.03671
# [7]	validation-rmse:30026.70082
# [8]	validation-rmse:30146.65623
# [9]	validation-rmse:29401.26019
# [10]	validation-rmse:28365.42363
# [11]	validation-rmse:27775.22572
# [12]	validation-rmse:27391.66981
# [13]	validation-rmse:27556.13792
# [14]	validation-rmse:27613.08171
# [15]	validation-rmse:27677.19967
# [16]	validation-rmse:27679.80393
# [17]	validation-rmse:28599.70974
# [18]	validation-rmse:28238.55056
# [19]	validation-rmse:28054.91209
# [20]	validation-rmse:27735.51465
# [21]	validation-rmse:27312.88544
# [22]	validation-rmse:27486.69268
# [23]	validation-rmse:27633.41815
# [24]	validation-rmse:27910.37853
# [25]	validation-rmse:28136.19572
# [26]	validation-rmse:27843.08857
# [27]	validation-rmse:26906.83765
# [28]	validation-rmse:27051.35884
# [29]	validation-rmse:26633.30401
# [30]	validation-rmse:26965.61138
# [31]	validation-rmse:27273.71824
# [32]	validation-rmse:27122.50666
# [33]	validation-rmse:27158.38657
# [34]	validation-rmse:27512.47059
# [35]	validation-rmse:26819.05141
# [36]	validation-rmse:27575.26205
# [37]	validation-rmse:27473.41793
# [38]	validation-rmse:27600.05222
# [39]	validation-rmse:27832.68346
# [40]	validation-rmse:27798.56940
# [41]	validation-rmse:27652.24219
# [42]	validation-rmse:28218.43477
# [43]	validation-rmse:28160.76367
# [44]	validation-rmse:28213.95073
# [45]	validation-rmse:28366.49203
# [46]	validation-rmse:27993.55605
# [47]	validation-rmse:28064.35045
# [48]	validation-rmse:27816.87061
# [49]	validation-rmse:28324.61626
# [50]	validation-rmse:28314.24223
# [51]	validation-rmse:28262.57365
# [52]	validation-rmse:28359.54208
# [53]	validation-rmse:28327.14107
# [54]	validation-rmse:28215.33218
# [55]	validation-rmse:28092.95840
# [56]	validation-rmse:28123.53894
# [57]	validation-rmse:27932.38511
# [58]	validation-rmse:27691.69510
# [59]	validation-rmse:27748.08026
# [60]	validation-rmse:27767.23658
# [61]	validation-rmse:27773.83397
# [62]	validation-rmse:27640.93921
# [63]	validation-rmse:27232.98203
# [64]	validation-rmse:27801.89079
# [65]	validation-rmse:28076.49828
# [66]	validation-rmse:27972.65507
# [67]	validation-rmse:27939.05795
# [68]	validation-rmse:28060.96341
# [69]	validation-rmse:28730.53656
# [70]	validation-rmse:28579.50776
# [71]	validation-rmse:28483.81184
# [72]	validation-rmse:28507.70108
# [73]	validation-rmse:28480.55917
# [74]	validation-rmse:28753.78547
# [75]	validation-rmse:28890.02388
# [76]	validation-rmse:28817.97861
# [77]	validation-rmse:28790.71299
# [78]	validation-rmse:28915.08589
# [12:53:14] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation-rmse
16] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation-rmse:161930.13875
# [1]	validation-rmse:131767.09720
# [2]	validation-rmse:107803.59968
# [3]	validation-rmse:88270.27650
# [4]	validation-rmse:72856.40825
# [5]	validation-rmse:60175.01060
# [6]	validation-rmse:50722.02861
# [7]	validation-rmse:42595.51521
# [8]	validation-rmse:36456.48819
# [9]	validation-rmse:32493.06308
# [10]	validation-rmse:29656.44292
# [11]	validation-rmse:27710.82357
# [12]	validation-rmse:26434.68442
# [13]	validation-rmse:26055.11495
# [14]	validation-rmse:25611.90886
# [15]	validation-rmse:25112.37219
# [16]	validation-rmse:24931.21948
# [17]	validation-rmse:24962.65870
# [18]	validation-rmse:24795.84591
# [19]	validation-rmse:25057.32547
# [20]	validation-rmse:25062.33352
# [21]	validation-rmse:24951.91692
# [22]	validation-rmse:25064.64681
# [23]	validation-rmse:25123.92818
# [24]	validation-rmse:25526.01706
# [25]	validation-rmse:25553.66219
# [26]	validation-rmse:25635.55564
# [27]	validation-rmse:25312.62351
# [28]	validation-rmse:25399.80698
# [29]	validation-rmse:25508.31708
# [30]	validation-rmse:25622.41640
# [31]	validation-rmse:25324.21861
# [32]	validation-rmse:25082.14514
# [33]	validation-rmse:25112.29273
# [34]	validation-rmse:25236.12972
# [35]	validation-rmse:25332.98894
# [36]	validation-rmse:25116.46186
# [37]	validation-rmse:25011.01979
# [38]	validation-rmse:25347.42351
# [39]	validation-rmse:25275.19146
# [40]	validation-rmse:25468.18446
# [41]	validation-rmse:25188.58184
# [42]	validation-rmse:25232.08575
# [43]	validation-rmse:25130.93466
# [44]	validation-rmse:25124.25907
# [45]	validation-rmse:24975.93900
# [46]	validation-rmse:24998.87804
# [47]	validation-rmse:25160.46181
# [48]	validation-rmse:25205.83025
# [49]	validation-rmse:25242.59499
# [50]	validation-rmse:25157.51677
# [51]	validation-rmse:25268.59734
# [52]	validation-rmse:25251.04330
# [53]	validation-rmse:25074.11436
# [54]	validation-rmse:25136.98841
# [55]	validation-rmse:25136.10069
# [56]	validation-rmse:25412.79653
# [57]	validation-rmse:25398.53253
# [58]	validation-rmse:25493.24129
# [59]	validation-rmse:25589.19740
# [60]	validation-rmse:25665.83438
# [61]	validation-rmse:25546.25756
# [62]	validation-rmse:25555.65884
# [63]	validation-rmse:25538.79712
# [64]	validation-rmse:25442.00022
# [65]	validation-rmse:25600.51129
# [66]	validation-rmse:25742.08522
# [67]	validation-rmse:25483.42377
# 100%|██████████████████| 10/10 [00:06<00:00,  1.65trial/s, best loss: 23924.365008568588]

# %%
def train_best_model(train, valid, test, y_test, dv):
    with mlflow.start_run():

        best_params = {
            'colsample_bytree': 0.9250870893919794,
            'gamma': 0.007995628667745471,
            'learning_rate': 0.20384373996439606,
            'max_depth': 4,
            'min_child_weight': 0.41092408055939844,
            'reg_alpha': 0.007444391334457018,
            'reg_lambda': 0.017392816466180783,
            'subsample': 0.7772671896767146,
            'seed': RANDOM_SEED
        }

        mlflow.log_params(best_params)

        model_xgb = xgb.train(
            params=best_params,
            dtrain=train,
            evals=[(valid, 'validation')],
            num_boost_round=2200,
            early_stopping_rounds=50)

        y_pred = model_xgb.predict(test)
        rmse = mean_squared_error(y_test, y_pred, squared=False)
        mlflow.log_metric("rmse", rmse)

        with open("../models/preprocessor.b", "wb") as f_out:
            pickle.dump(dv, f_out)
        mlflow.log_artifact("../models/preprocessor.b", artifact_path="preprocessor")

        mlflow.xgboost.log_model(model_xgb, artifact_path="models_mlflow")

# %%
train_best_model(train_xgb, valid_xgb, test_xgb, y_test, dv)
# Out:
# [12:53:16] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-3.7/xgboost/src/learner.cc:627:
# Parameters: { "n_estimators" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	validation-rmse:158494.29941
# [1]	validation-rmse:126484.51480
# [2]	validation-rmse:101066.17423
# [3]	validation-rmse:81220.04929
# [4]	validation-rmse:65258.07088
# [5]	validation-rmse:52934.61472
# [6]	validation-rmse:44064.58494
# [7]	validation-rmse:37790.94475
# [8]	validation-rmse:32820.68480
# [9]	validation-rmse:29195.42834
# [10]	validation-rmse:26515.86373
# [11]	validation-rmse:24829.85717
# [12]	validation-rmse:24181.78056
# [13]	validation-rmse:23545.26726
# [14]	validation-rmse:22802.64532
# [15]	validation-rmse:22222.40097
# [16]	validation-rmse:22270.32785
# [17]	validation-rmse:22007.41964
# [18]	validation-rmse:21984.39723
# [19]	validation-rmse:22045.26249
# [20]	validation-rmse:22302.41038
# [21]	validation-rmse:22164.61833
# [22]	validation-rmse:22150.94634
# [23]	validation-rmse:22022.33509
# [24]	validation-rmse:21962.55270
# [25]	validation-rmse:21918.48077
# [26]	validation-rmse:21974.00753
# [27]	validation-rmse:21852.12666
# [28]	validation-rmse:21787.53765
# [29]	validation-rmse:21893.82066
# [30]	validation-rmse:22115.96150
# [31]	validation-rmse:22066.32102
# [32]	validation-rmse:22210.73486
# [33]	validation-rmse:22164.34321
# [34]	validation-rmse:22346.65796
# [35]	validation-rmse:22360.08967
# [36]	validation-rmse:22156.36946
# [37]	validation-rmse:22213.45936
# [38]	validation-rmse:22311.20018
# [39]	validation-rmse:22344.28641
# [40]	validation-rmse:22168.63901
# [41]	validation-rmse:22397.93062
# [42]	validation-rmse:22407.26132
# [43]	validation-rmse:22433.13007
# [44]	validation-rmse:22501.85499
# [45]	validation-rmse:22478.54516
# [46]	validation-rmse:22493.57903
# [47]	validation-rmse:22459.82540
# [48]	validation-rmse:22465.21491
# [49]	validation-rmse:22523.33278
# [50]	validation-rmse:22535.69802
# [51]	validation-rmse:22525.68083
# [52]	validation-rmse:22556.03896
# [53]	validation-rmse:22595.16796
# [54]	validation-rmse:22511.39057
# [55]	validation-rmse:22514.06923
# [56]	validation-rmse:22539.36862
# [57]	validation-rmse:22306.37472
# [58]	validation-rmse:22293.81623
# [59]	validation-rmse:22199.86208
# [60]	validation-rmse:22259.26455
# [61]	validation-rmse:22339.97945
# [62]	validation-rmse:22399.31463
# [63]	validation-rmse:22433.46653
# [64]	validation-rmse:22437.02111
# [65]	validation-rmse:22330.88831
# [66]	validation-rmse:22333.59703
# [67]	validation-rmse:22300.26411
# [68]	validation-rmse:22290.07004
# [69]	validation-rmse:22408.87642
# [70]	validation-rmse:22420.79441
# [71]	validation-rmse:22404.73457
# [72]	validation-rmse:22169.00209
# [73]	validation-rmse:22086.02116
# [74]	validation-rmse:22093.51748
# [75]	validation-rmse:22172.09048
# [76]	validation-rmse:22161.78410
# [77]	validation-rmse:22146.65478
# [78]	validation-rmse:22193.35234
